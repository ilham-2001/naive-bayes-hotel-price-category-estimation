# %%
import pandas as pd

# %%
data = pd.read_csv("data/hotel.csv")
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1133                                Shangri-La Surabaya  5-star hotel    4.7
# 1134                         Ascott Waterplace Surabaya  5-star hotel    4.6
# 1135                                The Westin Surabaya  5-star hotel    4.8
# 1136                          Bumi Surabaya City Resort  5-star hotel    4.7
# 1137  Grand Kebonsari - Guest House & Homestay Syari'ah  5-star hotel    4.5
#
# ...
