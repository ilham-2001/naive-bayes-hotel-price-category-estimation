# %%
import pandas as pd

# %%
data = pd.read_csv("data/jakarta.csv")
data
# Out:
#                                                   Name         Class Rating  \
# 0                                     MK HOUSE TENDEAN  2-star hotel    4.4
# 1                             RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                               Green Bamboo Residence  2-star hotel    4.2
# 3                  RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4    Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ..                                                 ...           ...    ...
# 477                   Oakwood Suites La Maison Jakarta  5-star hotel    4.6
# 478                   Fraser Residence Menteng Jakarta  5-star hotel    4.6
# 479                          Fraser Residence Sudirman  5-star hotel    4.6
# 480  The Hermitage, a Tribute Portfolio Hotel, Jakarta  5-star hotel    4.6
# 481                        Ethan Hotel Cilincing Plaza  5-star hotel      4
#
# ...
