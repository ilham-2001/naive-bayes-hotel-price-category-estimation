# %%
import pandas as pd

# %%
data = pd.read_csv("data/surabaya.csv")
data
# Out:
#                                                   Name         Class Rating  \
# 0                                     Capsule Homestay  2-star hotel    3.9
# 1                    OYO 469 Bumi Banyu Bening Syariah  2-star hotel    4.3
# 2                                    POP! Hotel Gubeng  2-star hotel    4.2
# 3                                 Bella Hotel Surabaya  2-star hotel      4
# 4                      ibis budget Surabaya Diponegoro  2-star hotel    4.4
# ..                                                 ...           ...    ...
# 336                                Shangri-La Surabaya  5-star hotel    4.7
# 337                         Ascott Waterplace Surabaya  5-star hotel    4.6
# 338                                The Westin Surabaya  5-star hotel    4.8
# 339                          Bumi Surabaya City Resort  5-star hotel    4.7
# 340  Grand Kebonsari - Guest House & Homestay Syari'ah  5-star hotel    4.5
#
# ...
