# %%
import pandas as pd

# %%
data = pd.read_csv("data/hotel.csv")
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
# hilangkan data hotel yang tidak memiliki harga

data = data.drop(data[data.Price == '0'].index)

# %%
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
# hilangkan data hotel yang tidak memiliki rating bintang

data = data.drop(data[data.Class == '-'].index)

# %%
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
for i in data['Facility']:
    data_str = i.strip("[]")
    print(data_str)
# Out:
# 'Free Wi-Fi', 'Air conditioning', 'Full-service laundry', 'Child-friendly'
# 'Free Wi-Fi', 'Air conditioning', 'Child-friendly'
# 'Breakfast', 'Free Wi-Fi', 'Free parking', 'Air conditioning', 'Restaurant', 'Room service', 'Full-service laundry', 'Accessible'
# 'Free Wi-Fi', 'Outdoor pool'
# 'Breakfast', 'Free Wi-Fi', 'Free parking', 'Pool', 'Air conditioning', 'Restaurant', 'Room service', 'Airport shuttle'
# 'Breakfast ($)', 'Free Wi-Fi', 'Free parking', 'Air conditioning', 'Bar', 'Restaurant', 'Room service', 'Airport shuttle'
# 'Free Wi-Fi', 'Free parking', 'Outdoor pool', 'Air conditioning', 'Full-service laundry', 'Child-friendly'
# 'Free Wi-Fi', 'Air conditioning', 'Restaurant', 'Room service', 'Full-service laundry'
# 'Free breakfast', 'Free Wi-Fi', 'Free parking', 'Air conditioning', 'Restaurant', 'Room service', 'Full-service laundry', 'Accessible'
# 'Free breakfast', 'Free Wi-Fi', 'Air conditioning', 'Restaurant', 'Room service', 'Full-service laundry', 'Child-friendly'
# ...

# %%
# Punya AC atau tidak?
hasAC = []

for i in data['Facility']:
    data_str = i.strip("[]")

    if "Air conditioning" in data_str:
        hasAC.append(True)
    else:
        hasAC.append(False)

data = data.assign(AirConditioner=hasAC)
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
# Punya Bar atau tidak?
hasBar = []

for i in data['Facility']:
    data_str = i.strip("[]")

    if "Bar" in data_str:
        hasBar.append(True)
    else:
        hasBar.append(False)

data = data.assign(Bar=hasBar)
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
# Punya Kolam Renang atau tidak?
hasPool = []

for i in data['Facility']:
    data_str = i.strip("[]")

    if "pool" in data_str:
        hasPool.append(True)
    else:
        hasPool.append(False)

data = data.assign(Pool=hasPool)
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
# Punya Spa atau tidak?
hasSpa = []

for i in data['Facility']:
    data_str = i.strip("[]")

    if "Spa" in data_str:
        hasSpa.append(True)
    else:
        hasSpa.append(False)

data = data.assign(Spa=hasSpa)
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
# Punya Fitnees center atau tidak?
hasFitness = []

for i in data['Facility']:
    data_str = i.strip("[]")

    if "Fitness centre" in data_str:
        hasFitness.append(True)
    else:
        hasFitness.append(False)

data = data.assign(FitenessCenter=hasFitness)
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
# Punya Restaurant atau tidak?
hasRestaurant = []

for i in data['Facility']:
    data_str = i.strip("[]")

    if "Restaurant" in data_str:
        hasRestaurant.append(True)
    else:
        hasRestaurant.append(False)

data = data.assign(Restaurant=hasRestaurant)
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
# Punya Hot tub atau tidak?
hasHotTub = []

for i in data['Facility']:
    data_str = i.strip("[]")

    if "Hot tub" in data_str:
        hasHotTub.append(True)
    else:
        hasHotTub.append(False)

data = data.assign(HotTub=hasHotTub)
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
# ubah price mennjadi integer
price = data['Price']
prices_data = []

for p in price:
    p = p.replace('IDR ', '')
    p = int(p.replace(',', ''))
    prices_data.append(p)

data = data.assign(Price_IDR=prices_data)

data = data.drop(['Price'], axis=1)
data
# Out:
#                                                    Name         Class Rating  \
# 0                                      MK HOUSE TENDEAN  2-star hotel    4.4
# 1                              RedDoorz @ Cempaka Putih  2-star hotel    4.4
# 2                                Green Bamboo Residence  2-star hotel    4.2
# 3                   RedDoorz Premium @ Cilandak Timur 2  2-star hotel    4.5
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...  2-star hotel    4.2
# ...                                                 ...           ...    ...
# 1576                                     Hilton Bandung  5-star hotel    4.7
# 1577                               The Papandayan Hotel  5-star hotel    4.6
# 1578                    Sheraton Bandung Hotel & Towers  5-star hotel    4.6
# 1579                      Pullman Bandung Grand Central  5-star hotel    4.7
# 1580                 Crowne Plaza Bandung, an IHG Hotel  5-star hotel    4.6
#
# ...

# %%
hotelStar = data['Class']
hotelNew = []

for x in hotelStar:
  x = x.replace("-star hotel", "")
  x = int(x)
  hotelNew.append(x)

data = data.assign(hotelClass=hotelNew)
data = data.drop(['Class'], axis=1)

data
# Out:
#                                                    Name Rating Total Rater  \
# 0                                      MK HOUSE TENDEAN    4.4       (548)
# 1                              RedDoorz @ Cempaka Putih    4.4       (169)
# 2                                Green Bamboo Residence    4.2     (1,630)
# 3                   RedDoorz Premium @ Cilandak Timur 2    4.5       (243)
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...    4.2     (4,237)
# ...                                                 ...    ...         ...
# 1576                                     Hilton Bandung    4.7     (8,164)
# 1577                               The Papandayan Hotel    4.6     (7,894)
# 1578                    Sheraton Bandung Hotel & Towers    4.6     (5,260)
# 1579                      Pullman Bandung Grand Central    4.7     (2,336)
# 1580                 Crowne Plaza Bandung, an IHG Hotel    4.6     (8,801)
#
#                                                Facility     Area  \
# ...

# %%
data = data.drop(['Facility'], axis=1)
data
# Out:
#                                                    Name Rating Total Rater  \
# 0                                      MK HOUSE TENDEAN    4.4       (548)
# 1                              RedDoorz @ Cempaka Putih    4.4       (169)
# 2                                Green Bamboo Residence    4.2     (1,630)
# 3                   RedDoorz Premium @ Cilandak Timur 2    4.5       (243)
# 4     Zest Airport Jakarta by Swiss-Belhotel Interna...    4.2     (4,237)
# ...                                                 ...    ...         ...
# 1576                                     Hilton Bandung    4.7     (8,164)
# 1577                               The Papandayan Hotel    4.6     (7,894)
# 1578                    Sheraton Bandung Hotel & Towers    4.6     (5,260)
# 1579                      Pullman Bandung Grand Central    4.7     (2,336)
# 1580                 Crowne Plaza Bandung, an IHG Hotel    4.6     (8,801)
#
# ...

# %%
data.to_csv('data/hotel_preprocess_v2.csv')
