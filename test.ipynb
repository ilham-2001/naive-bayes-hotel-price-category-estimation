# %%
import pandas as pd

# %%
data = pd.read_csv("data/bandung.csv")
data
# Out:
#                                        Name         Class  Rating Total Rater  \
# 0           ibis budget Bandung Asia Afrika  2-star hotel     4.2     (4,151)
# 1          RedDoorz Plus near Asia Afrika 3  2-star hotel     4.2       (425)
# 2           ibis budget Bandung Asia Afrika  2-star hotel     4.2     (4,151)
# 3    POP! Hotel Festival Citylink - Bandung  2-star hotel     4.3     (4,306)
# 4                         Dago's Hill Hotel  2-star hotel     4.3       (213)
# ..                                      ...           ...     ...         ...
# 438                          Hilton Bandung  5-star hotel     4.7     (8,164)
# 439                    The Papandayan Hotel  5-star hotel     4.6     (7,894)
# 440         Sheraton Bandung Hotel & Towers  5-star hotel     4.6     (5,260)
# 441           Pullman Bandung Grand Central  5-star hotel     4.7     (2,336)
# 442      Crowne Plaza Bandung, an IHG Hotel  5-star hotel     4.6     (8,801)
#
# ...
